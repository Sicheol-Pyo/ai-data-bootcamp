# %%
import pandas as pd
from sqlalchemy import create_engine

# CSV 파일 읽기
df = pd.read_csv('C:/mysql-files/amazon.csv')

# MySQL 연결 (사용자명, 비밀번호는 본인 환경에 맞게 수정)
engine = create_engine('mysql+pymysql://사용자명:비밀번호@localhost/db02')

# 이미 만들어둔 db02.amazon 테이블에 데이터 삽입
df.to_sql('amazon', con=engine, if_exists='append', index=False)

print(f"{len(df)}개 행 삽입 완료")

# %%
import requests
rate = requests.get('https://api.exchangerate-api.com/v4/latest/INR').json()['rates']['KRW']
print(rate)
# Out:
# 14.45
